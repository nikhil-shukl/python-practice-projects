# %% [markdown]
# 1️⃣ Named Entity Recognition (NER) kya hota hai?
#
# NER ka matlab:
#
# Text ke andar jo REAL-WORLD cheezein hoti hain
# (jaise naam, jagah, date, paisa, organization)
# unko identify + classify karna.
#
# Simple words me:
# 👉 “Yeh word normal noun hai ya real duniya ka entity?”
#
# Example sentence:
#
# “The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel.”
#
# NER bolega:
#
# Eiffel Tower → Location / Place
#
# 1887 – 1889 → Date
#
# French → Nationality
#
# Gustave Eiffel → Person

# %%
import nltk
from nltk import word_tokenize, pos_tag

sentence = "The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel"

# Step 1: Tokenize
words = word_tokenize(sentence)

# Step 2: POS tagging
pos_tags = pos_tag(words)

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Nikki\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# True

# %%
from nltk import ne_chunk

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Nikki\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
import nltk
nltk.data.find('chunkers/maxent_ne_chunker')
# Out:
# FileSystemPathPointer('C:\\Users\\Nikki\\AppData\\Roaming\\nltk_data\\chunkers\\maxent_ne_chunker')

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp("The Eiffel Tower was built by Gustave Eiffel in Paris")

for ent in doc.ents:
    print(ent.text+"-->"+ent.label_)
# Out:
# The Eiffel Tower-->LOC
# Gustave Eiffel-->PERSON
# Paris-->GPE

# %% [markdown]
# spaCy ek modern aur powerful Natural Language Processing (NLP) library hai jo Python me use hoti hai.
# Isse text ko samajhne aur process karne ke liye alag-alag tools ko manually likhne ki zarurat nahi hoti, kyunki spaCy ek complete, all-in-one NLP pipeline provide karta hai.
#
# spaCy me jab hum ek simple line me text ko process karte hain, to library automatically andar hi andar kai important NLP tasks perform kar leti hai, jaise:
#
# Sentence Segmentation – paragraph ko sentences me todna
#
# Tokenization – sentence ko words/tokens me convert karna
#
# Part of Speech (POS) Tagging – har word ka grammatical role batana
#
# Lemmatization – word ka actual root form nikalna
#
# Dependency Parsing – words ke beech relationship samajhna
#
# Named Entity Recognition (NER) – person, place, organization, date, money jaise real-world entities identify karna
#
# Ye sab kaam spaCy pre-trained machine learning models ki madad se karta hai, isliye user ko na to alag-alag models download karne padte hain aur na hi complex configuration karni padti hai.
#
# Isi wajah se spaCy:
#
# Beginner-friendly hai
#
# Fast aur stable hai
#
# Real-world aur industry projects me widely use hota hai
